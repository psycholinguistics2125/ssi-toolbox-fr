# %%
question_data = [
    {
        "label": "Introductory", #Introduction
        "exemples": [
            "Pouvez-vous me parler de votre expérience en tant que...",
            "Parlons un peu de votre implication dans...",
            "Comment décririez-vous votre relation avec. ..",
            "Pour commencer, pouvez-vous me parler de ...",
            "Pour démarer, pouvez-vous me raconter...",

        ]
    },
    {
        "label": "FollowUp", #Question de suivi
        "exemples": [
            "D'accord, ok.",
            "Je vois.",
            "Je comprends.",
            "D'accord, je vois.",
            "Comme vous voulez.",
            "Vous pouvez continuer.",

        ]
    },
    {
        "label": "Probing", # Approfondissement"
        "exemples": [
            "Pouvez-vous en dire un peu plus sur votre perspective concernant...",
            "Pourquoi pensez-vous que cette situation est importante ?",
            "Quels sont les éléments qui contribuent à votre point de vue sur..."
            "Pourriez-vous approfondir ce point ?",
            "Revenons sur ce que vous avez mentionné à propos de...",
            "J'aimerai en savoir plus sur ce que vous avez dit à propos de...",
            "Pouvez-vous réfléchir davantage à cette idée ?",

        ]
    },
    {
        "label": "Specifying", # Spécifier
        "exemples": [
            "Pourriez-vous me donner un exemple concret de...",
            "Pouvez-vous préciser votre pensée en donnant un exemple de...",
            "Auriez-vous un cas spécifique à l'esprit en parlant de..."
            "Comment avez-vous appris la nouvelle de... ?",
            "Pouvez-vous essayer de reconstituer la chronologie des événements ?",
            "Quelles émotions spécifiques avez-vous ressenties à ce moment-là ?",
            "Est-ce que vous connaissez personnellement, ou indirectement, des personnes .. ?",
            "Quelle est votre relation avec... ?",
            "A quelle fréquence avez-vous ... ?",
            "Pour quelle durée avez-vous ... ?",
            "A ce moment-la, qu'est-ce que vous avez fait ?",
            "A ce moment-la, qu'est-ce que vous avez ressenti ?",
            "A cet instant, quelle fut votre réaction ?",
            "Comment vous êtes-vous senti lorsque cela s'est produit ?",
            
        ]
    },
    
    {
        "label": "Structuring", #Structurant"
        "exemples": [
            "Merci pour ces informations. Passons maintenant à un autre sujet...",
            "J'apprécie votre point de vue. Abordons un aspect différent...",
            "J'aimerais maintenant passer à un autre sujet...",
            "Passons maintenant à ...",
            "Revenons à notre sujet principal de discussion...",
            "Avant de conclure cette partie, j'aimerais aborder...",
        ]
    },
    {
        "label": "DirectQuestion", #Question directe
        "exemples": [
            "Lorsque vous mentionnez X, pensez-vous à Y ou à Z ?",
            "Pouvez-vous clarifier votre pensée en comparant X et Y ?",
            "Avez-vous des réflexions sur la relation entre X et Y ?"
            "Quelle est votre opinion sur... ?",
            "Pouvez-vous me parler de votre rapport aux ... ?",
            "De manière plus générale, pouvez-vous me dire comment vous interprétez... ?",
            "Avec qui avez-vous discuté de... ?",
            "Parlez-moi de votre réaction émotionnelle à...",
            "Quelles étaient vos émotions pendant cette période ?",
            "Quelles ont été vos premières réactions à... ?",
        ]
    },
    {
        "label": "IndirectQuestion", # Question indirect"
        "exemples": [
            "Comment pensez-vous que d'autres personnes perçoivent ce sujet ?",
            "Quelle pourrait être la perspective des autres sur...",
            "Avez-vous une idée de comment cela est généralement perçu par les autres ?",
            "Selon vous, comment les gens pourraient-ils interpréter cette situation ?",
            "Quelle pourrait être la réaction des autres à ce sujet ?",
            "Pouvez-vous commenter l'opinion collective sur... ?",
        ]
    },
    {
        "label": "Interpreting", #Interprétation
        "exemples": [
            "Donc, si je comprends bien, vous pensez que...",
            "Résumons brièvement votre perspective :...",
            "Il semble que vous suggérez que...",
            "Selon vous, qu'est-ce qui a conduit à...",
            "Estimez-vous que ces évement ont eu des conséquences sur ... ?",
            "Est-ce que vous pensez que cela a eu un impact sur... ?",
            "Est-ce que vous feriez le lien entre... et... ?",
            "Ai-je raison de comprendre que vous ressentez ... ?",
            "Je veux m'assurer de suivre correctement. Est-il exact de dire que vous croyez [une idée spécifique] ?",
            "Pour clarifier, dites-vous que ... ?",
            "Permettez-moi de confirmer ma compréhension. Vous avez mentionné ... ; est-ce correct ?",
            "Je veux m'assurer de capturer votre perspective correctement. Êtes-vous d'accord avec ... ?",
            "Si je comprends bien, vous exprimez .... Est-ce exact ?",
            "Juste pour clarifier, quand vous mentionnez [...], vous voulez dire [...], c'est bien ça ?",
            "J'essaie de comprendre pleinement votre point de vue. Pouvez-vous confirmer si j'ai bien saisi avec [interprétation reformulée] ?"
  
        ]
    },
    {
        "label": "Ending", #Fin de l'entretien
        "exemples": [
            "J'ai posé toutes les questions que j'avais, mais y a-t-il quelque chose d'autre à propos de votre expérience que nous n'avons pas abordé ?",
            "Avez-vous des points supplémentaires que vous aimeriez partager avant de conclure ?",
            "Est-ce qu'il y a quelque chose que vous souhaitez ajouter ou discuter avant de terminer l'entretien ?",
            "Nous avons couvert beaucoup de choses. Avez-vous des questions à me poser ?",
            "Nous avons terminez la première partie de l'entretien. Est-ce que vous souhaitez ajouter quelque chose ?",
        ]
    }
]


question_themes = [
    {
        "label" : "PersonalExperience",
        "exemple" : [
            "Pourriez-vous me raconter le 13 novembre 2015 ?",
            "Pourriez-vous me parler de votre expérience en tant que témoin des attentats du 13 novembre 2015 ?",

        ]
    },
    {
        "label": "Nouvelle",
        "exemple" : [
            "Comment avez-vous appris la nouvelle des attentats ? Par quel biais ?",
            "Où étiez-vous quand vous avez appris la nouvelle?",
             "Que faisiez-vous quand vous avez appris la nouvelle ?",
            "Avec qui étiez-vous quand vous avez appris la nouvelle?"
        ]

    },
    {
        "label": "Reaction",
        "exemple" : [
            "Quelle fut votre première réaction ? ",
            "Qu’avez-vous d’abord pensé à ce moment-là ?",
            "Avez-vous ressenti un besoin d’agir ? Ou bien, au contraire, un sentiment d’impuissance ? ",
            "Qu’avez-vous fait au cours du week-end, des jours qui ont suivi ?"
        ]

    },
     {
        "label": "Temps",
        "exemple" : [
            "Avez-vous ressenti un changement dans l’écoulement du temps au cours de ces événements ?",
            "La sensation que le temps s’accélérait, ou au contraire de vivre les choses comme au ralenti ? ",
            "Avez-vous eu des difficultés à revenir à la normale ? ",
            "Les jours qui ont suivi les attentats vous ont-ils semblé différents ou pas ? "
        ]

    },
     {
        "label": "Media",
        "exemple" : [
            "Pourriez-vous parler de votre rapport aux médias en lien avec ces événements ?",
            "Quels médias avez-vous consultés (télé / radio / Internet / réseaux sociaux) ?",
            "À quelle fréquence et pour quelle durée environ ? ",
            "« Et pour quels usages ? Pour obtenir des informations, ou pour trouver des analyses, des explications ?"
        ]

    },
    {
        "label": "Lieux",
        "exemple" : [
            "Est-ce que vous connaissez personnellement les lieux où se sont déroulés les attentats ? Les endroits précis, les quartiers, la ville de Paris ? ",
            "Êtes-vous venu, ou revenu, sur les lieux des attentats depuis novembre 2015 ?",
        ]

    },
    {
        "label": "Connaissance",
        "exemple" : [
            " Est-ce que vous connaissez personnellement, ou indirectement, des personnes touchées par les attaques, des victimes ?",
        ]

    },
    {
        "label": "Reconstitution",
        "exemple" : [
            "Pouvez-vous essayer de reconstituer la chronologie des événements ? C’est-à-dire, d’après vos souvenirs, quels sont l’ordre et les lieux dans lesquels les attaques se sont déroulées ?",
        ]

    },
    {
        "label" : "CauseConsequences",
        "exemple" : [ 
            "De manière plus générale, pouvez-vous me dire comment vous interprétez les attentats du 13 novembre 2015 ? C’est-à-dire, à votre avis / selon vous, quelles sont les causes et les conséquences de ces événements ?",
            "Selon vous, quelles ont pu être les causes de ces attentats ?",
            "Est-ce que vous feriez des liens entre ces attentats et d’autres événements (en France ou dans le reste du monde, passés ou contemporains) ?",
            "Selon vous, quelles ont été les conséquences de ces attentats ? ",
            "Estimez-vous que ces attentats ont eu une répercussion sur votre vie quotidienne ? Ont changé quelque chose pour vous et vos proches ? Et dans la société française, ou le monde en général ?"]
    }
]

data = pd.DataFrame(question_themes).explode('exemple').reset_index(drop=True)
data = data.rename(columns={"exemple": "text"})
data['label'] = data['label'].apply(lambda x : [x])
data2 = pd.read_json("themes_annotation.json")
#data.to_csv('guide.csv',sep = "\t", index=False)

to_train = pd.concat([data,data2], ignore_index=True).reset_index(drop=True)

# %%
to_train = to_train.drop(columns=['id'])

# %%
labels = list(set(flatten_list(to_train.label.tolist())))
print(labels)
labels_dict = {k:j for j, k in enumerate(labels)}
print(labels_dict)
# Out:
# ['CauseConsequences', 'PersonalExperience', 'Connaissance', 'Other', 'Reconstitution', 'Temps', 'Reaction', 'Nouvelle', 'Media', 'Lieux']
# {'CauseConsequences': 0, 'PersonalExperience': 1, 'Connaissance': 2, 'Other': 3, 'Reconstitution': 4, 'Temps': 5, 'Reaction': 6, 'Nouvelle': 7, 'Media': 8, 'Lieux': 9}
